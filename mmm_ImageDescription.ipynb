# %%
from transformers import pipeline
from PIL import Image
from IPython.display import display

# %%
imagepath="/content/Magic8ball.jpg"
image=Image.open(imagepath)

display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=475x475>

# %%
def describeImage(image):
    descriptor = pipeline(
            "image-to-text",
            model="Salesforce/blip-image-captioning-base")

    description = descriptor(image)[0]['generated_text']
    return description

# %%
describeImage(image)
# Out:
# Device set to use cpu
# 'a black and white ball with a number eight eight'
